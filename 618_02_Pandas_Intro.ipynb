# %% [markdown]
# # SI 618: Data Manipulation and Analysis
# ## 02 - Introduction to pandas
# ### Dr. Chris Teplovs, School of Information, University of Michigan
# <small><a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc-sa/4.0/88x31.png" /></a>This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License</a>.

# %% [markdown]
# ## Objectives:
# * Know how to manipulate Series and DataFrame
# * Draw a random sample of data
# * Select subset of data using boolean masking
# * Compute descriptive and summary statistics
# * Discretize continuous variables
# * Sort Series/DataFrame by index or column
# * Group data and calculate aggregate statistics
# * Use vectorized string methods
# * Make basic plots (scatter plot, histogram, bar chart, etc)
#
# ## Submission Instructions:
# Please turn in this Jupyter notebook file (both .ipynb and .html formats) on Canvas before you leave the classroom. Try to get through as much as you can.

# %% [markdown]
# ### IMPORTANT: Replace ```?``` in the following code with your uniqname.

# %%
MY_UNIQNAME = 'xinyexu'

# %% [markdown]
# ## Preface
# This lab consists of Part 0, Part 1 and Part 2. Part 0 is an introduction to some Pandas basics. There are no points assocaited with Part 0 but we will be covering it in class. Part 1 is based on a survey dataset and Part 2 uses movies and cast data. We will guide you through Part 1, and let you work on Part 2 on your own.
#
# **Question 0 is worth 2 points.  Questions 1-12 are worth 1 point each.  Questions 13-23 are worth 2 points each.**

# %% [markdown]
# ### Question 0 (2 points, 0.5 points each):
# What is the output of pandas.DataFrame.describe()? (Chapter 5)
#
#     put the basic summary of the dataframe: count, min, max, mean, std, some quantiles.
#
# What is the output of value_counts() work? (Chapter 5)
#
#     Return counts of each unique values. And it will be in descending order so that the first element is the most frequently-occurring element. Excludes NA values by default.
#
# What’s the difference between a series & a dataframe? (Chapter 5)
#
#     Dataframe is two-dimensional size-mutable, potentially heterogeneous tabular data structure with labeled axes (rows and columns).
#     Series is the datastructure for a single column of a DataFrame. It's one dimentional.
#
# Explain what foo_bar.groupby(’A’).sum() returns (Data Wrangling with Python and Pandas 1.9)
#
#     It calculates the sum of foo_bar values which is belonging to the group of 'A'. 'A' might be the another category in other columns.

# %% [markdown]
# ## Part 0: Background

# %% [markdown]
# ![](assets/02.002.png)

# %% [markdown]
# ![](assets/02.003.png)

# %% [markdown]
# ![](assets/02.004.png)

# %% [markdown]
# * less looping over elements
# * lots of built-in functionality
# * a "paradigm shift"

# %% [markdown]
# ![](assets/02.005.png)

# %% [markdown]
# ![](assets/02.006.png)

# %% [markdown]
# ![](assets/02.007.png)

# %% [markdown]
# ![](assets/02.008.png)

# %% [markdown]
# ![](assets/02.009.png)

# %% [markdown]
# ![](assets/02.010.png)

# %% [markdown]
# ![](assets/02.011.png)

# %% [markdown]
# # Data structures
#
# We're all familiar with lists:

# %%
names = ["Charlotte", "Ingrid", "Ian", "Eric"]
scores = [80, 95, 85, 70]

# %% [markdown]
# Now let's say that we wanted to divide each of those scores by two and assign the results to another variable. Go ahead and write some code that does that... There are lots of ways to do this, so go ahead and write one way to do it (without importing any additional python packages) and assign the results to a
# variable called ```half```:

# %%
half = [0.5 * score for score in scores]

# %% [markdown]
# If you followed the above instructions, the following cell block should print
# a list of floats that looks like ```
# [40.0, 47.5, 42.5, 35.0]```

# %%
half
# Out:
# [40.0, 47.5, 42.5, 35.0]

# %% [markdown]
# We can put data into an array structure that allows us to apply more powerful
# functions.  The data structure that we're interested in is called an ```ndarray``` and is from the ```numpy``` package:

# %%
import numpy as np
ascores = np.array(scores)

# %%
ascores
# Out:
# array([80, 95, 85, 70])

# %%
ahalf = ascores / 2 # array: support universal functions

# %%
ahalf
# Out:
# array([40, 47, 42, 35])

# %% [markdown]
# Numpy arrays are powerful, but they have some limitations:  they can only
# consist of one type of data (e.g. int), etc.  pandas provides two additional
# data structures that are built on numpy ndarrays.
#
# The first are Series.  Let's create a simple pandas Series and examine it:

# %%
import pandas as pd

# %%
sscores = pd.Series(scores,name='the_scores') # the name would become the column name when get together

# %%
sscores
# Out:
# 0    80
# 1    95
# 2    85
# 3    70
# Name: the_scores, dtype: int64

# %% [markdown]
# So you see a couple of useful things: an index (0 to 3) and a data type (dtype), which in this case is an int64.
#
# **A Series is a one-dimensional ndarray with axis labels**

# %%
data = dict(zip(names,scores))
dict(zip(names,scores))
# Out:
# {'Charlotte': 80, 'Eric': 70, 'Ian': 85, 'Ingrid': 95}

# %%
zip(names,scores)
# Out:
# [('Charlotte', 80), ('Ingrid', 95), ('Ian', 85), ('Eric', 70)]

# %%
data
# Out:
# {'Charlotte': 80, 'Eric': 70, 'Ian': 85, 'Ingrid': 95}

# %%
import pandas as pd

# %%
xdata = data

# %%
sData = pd.Series(data=xdata,name='score')  # put the mouse in the right side of (, then shift + tab => rules of function

# %%
sData
# Out:
# Charlotte    80
# Eric         70
# Ian          85
# Ingrid       95
# Name: score, dtype: int64

# %% [markdown]
# So Series are a bit friendlier than numpy arrays, but they're still only one-dimensional.  Keep in mind that our basic data abstraction is a table, which can
# be thought of as a two-dimensional array.  Let's go ahead and create a simple DataFrame with just one column:

# %%
pd.DataFrame(scores,index=names,columns=['score'])
# Out:
#            score
# Charlotte     80
# Ingrid        95
# Ian           85
# Eric          70

# %% [markdown]
# Let's return to the code we ran last time and walk though it just to make sure we understand it

# %%
df_names = pd.read_csv('data/names.csv')
df_names.head()
# Out:
#      name gender  birth_count  year
# 0  Simeon      M           23  1880
# 1   Raoul      M            7  1880
# 2     Lou      M           14  1880
# 3    Myra      F           83  1880
# 4   Alois      M           10  1880

# %% [markdown]
# Actually, that CSV file was created from a number of smaller CSV files.  Here's
# the code that will load the set of smaller CSV files:

# %%
years = range(1880, 2015)
pieces = []
for year in years:
    path = 'data/names/yob%d.csv' % year
    frame = pd.read_csv(path)
    frame['year'] = year
    pieces.append(frame) # why we need to append to pieces?
df_names = pd.concat(pieces, ignore_index=True)

# %%
df_names.head()
# Out:
#      name gender  birth_count  year
# 0  Simeon      M           23  1880
# 1   Raoul      M            7  1880
# 2     Lou      M           14  1880
# 3    Myra      F           83  1880
# 4   Alois      M           10  1880

# %% [markdown]
# Let's discuss what just happened there.

# %% [markdown]
# # Part 1 (as a group): Mental Health Disorders In the Tech Workplace
# From https://www.kaggle.com/osmi/mental-health-in-tech-survey

# %% [markdown]
# ## Data Description
#
# This dataset is from a 2014 survey that measures attitudes towards mental health and frequency of mental health disorders in the tech workplace.

# %% [markdown]
# ## Metadata
#
# **Timestamp**
#
# **Age**
#
# **Gender**
#
# **Country**
#
# **state**: If you live in the United States, which state or territory do you live in?
#
# **self_employed**: Are you self-employed?
#
# **family_history**: Do you have a family history of mental illness?
#
# **treatment**: Have you sought treatment for a mental health condition?
#
# **work_interfere**: If you have a mental health condition, do you feel that it interferes with your work?
#
# **no_employees**: How many employees does your company or organization have?
#
# **remote_work**: Do you work remotely (outside of an office) at least 50% of the time?
#
# **tech_company**: Is your employer primarily a tech company/organization?
#
# **benefits**: Does your employer provide mental health benefits?
#
# **care_options**: Do you know the options for mental health care your employer provides?
#
# **wellness_program**: Has your employer ever discussed mental health as part of an employee wellness program?
#
# **seek_help**: Does your employer provide resources to learn more about mental health issues and how to seek help?
#
# **anonymity**: Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources?
#
# **leave**: How easy is it for you to take medical leave for a mental health condition?
#
# **mental_health_consequence**: Do you think that discussing a mental health issue with your employer would have negative consequences?
#
# **phys_health_consequence**: Do you think that discussing a physical health issue with your employer would have negative consequences?
#
# **coworkers**: Would you be willing to discuss a mental health issue with your coworkers?
#
# **supervisor**: Would you be willing to discuss a mental health issue with your direct supervisor(s)?
#
# **mental_health_interview**: Would you bring up a mental health issue with a potential employer in an interview?
#
# **phys_health_interview**: Would you bring up a physical health issue with a potential employer in an interview?
#
# **mental_vs_physical**: Do you feel that your employer takes mental health as seriously as physical health?
#
# **obs_consequence**: Have you heard of or observed negative consequences for coworkers with mental health conditions in your workplace?
#
# **comments**: Any additional notes or comments

# %% [markdown]
# Let's load the usual libraries and also ask for plots to be rendered inside the notebook:

# %%
import numpy as np
import pandas as pd
 # inline: % magic comment, tells the jupyter display right in the notebook.
# %matplotlib inline

# %% [markdown]
# Then read the CSV file into a DataFrame:

# %%
df = pd.read_csv("data/survey.csv")

# %% [markdown]
# It's common to look at the resulting DataFrame using .head()

# %%
df.head() # df.tail()
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees   ...     \
# 0             No       Yes          Often            6-25   ...
# 1             No        No         Rarely  More than 1000   ...
# 2             No        No         Rarely            6-25   ...
# 3            Yes       Yes          Often          26-100   ...
# 4             No        No          Never         100-500   ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# 1          Don't know                     Maybe                      No
# 2  Somewhat difficult                        No                      No
# 3  Somewhat difficult                       Yes                     Yes
# 4          Don't know                        No                      No
#
#       coworkers supervisor mental_health_interview phys_health_interview  \
# 0  Some of them        Yes                      No                 Maybe
# 1            No         No                      No                    No
# 2           Yes        Yes                     Yes                   Yes
# 3  Some of them         No                   Maybe                 Maybe
# 4  Some of them        Yes                     Yes                   Yes
#
#   mental_vs_physical obs_consequence comments
# 0                Yes              No      NaN
# 1         Don't know              No      NaN
# 2                 No              No      NaN
# 3                 No             Yes      NaN
# 4         Don't know              No      NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# If you want to look at a random sample, you can use .sample()

# %%
df.sample(5)
# Out:
#                 Timestamp  Age  Gender        Country state self_employed  \
# 954   2014-08-29 02:10:57   38    Male  United States    TN            No
# 1050  2014-08-29 11:32:44   26  female  United States    WA            No
# 820   2014-08-28 14:52:46   40  Female  United States    WA            No
# 121   2014-08-27 12:33:00   25    Male  United States    DC            No
# 184   2014-08-27 12:52:08   43    Male  United States    WA            No
#
#      family_history treatment work_interfere    no_employees  \
# 954              No        No            NaN            6-25
# 1050            Yes       Yes      Sometimes  More than 1000
# 820             Yes       Yes      Sometimes         100-500
# 121              No        No            NaN          26-100
# 184             Yes       Yes          Often  More than 1000
#
#                             ...                                   leave  \
# 954                         ...                              Don't know
# 1050                        ...                              Don't know
# 820                         ...                              Don't know
# 121                         ...                               Very easy
# 184                         ...                          Very difficult
#
#      mental_health_consequence phys_health_consequence     coworkers  \
# 954                      Maybe                      No  Some of them
# 1050                        No                      No  Some of them
# 820                        Yes                   Maybe  Some of them
# 121                         No                      No  Some of them
# 184                        Yes                   Maybe            No
#
#      supervisor mental_health_interview phys_health_interview  \
# 954         Yes                   Maybe                 Maybe
# 1050        Yes                      No                 Maybe
# 820          No                      No                    No
# 121         Yes                      No                    No
# 184          No                      No                    No
#
#      mental_vs_physical obs_consequence  \
# 954          Don't know              No
# 1050                 No             Yes
# 820          Don't know              No
# 121          Don't know              No
# 184                  No              No
#
#                                                comments
# 954               Some of these should not be required.
# 1050  I should note one of the places my employer fa...
# 820                                                 NaN
# 121                                                 NaN
# 184                                                 NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# Finally, you can get some basic information about the size and shape of the DataFrame:

# %%
print("The number of rows of the dataset is: ", len(df))
print("The number of columns of the dataset is: ", len(df.columns))
print("The shape of the dataset is: ", df.shape)
# Out:
# ('The number of rows of the dataset is: ', 1259)
# ('The number of columns of the dataset is: ', 27)
# ('The shape of the dataset is: ', (1259, 27))

# %% [markdown]
# You can list the columns:

# %%
df.columns # get columns name
# Out:
# Index([u'Timestamp', u'Age', u'Gender', u'Country', u'state', u'self_employed',
#        u'family_history', u'treatment', u'work_interfere', u'no_employees',
#        u'remote_work', u'tech_company', u'benefits', u'care_options',
#        u'wellness_program', u'seek_help', u'anonymity', u'leave',
#        u'mental_health_consequence', u'phys_health_consequence', u'coworkers',
#        u'supervisor', u'mental_health_interview', u'phys_health_interview',
#        u'mental_vs_physical', u'obs_consequence', u'comments'],
#       dtype='object')

# %% [markdown]
# And you can extract one or more columns.  The following pair of
# commands do exactly the same thing:

# %%
print(df['Country']) # that's a series
# Out:
# 0        United States
# 1        United States
# 2               Canada
# 3       United Kingdom
# 4        United States
# 5        United States
# 6        United States
# 7               Canada
# 8        United States
# 9               Canada
# 10       United States
# 11            Bulgaria
# 12       United States
# 13       United States
# 14              Canada
# 15       United States
# 16      United Kingdom
# 17       United States
# 18       United States
# 19              France
# 20       United States
# 21       United States
# 22       United States
# 23       United States
# 24       United States
# 25       United States
# 26       United States
# 27       United States
# 28       United States
# 29      United Kingdom
#              ...
# 1229            Greece
# 1230    United Kingdom
# 1231    United Kingdom
# 1232    United Kingdom
# 1233    United Kingdom
# 1234    United Kingdom
# 1235            Canada
# 1236     United States
# 1237           Ireland
# 1238     United States
# 1239       Netherlands
# 1240           Germany
# 1241            Poland
# 1242           Ireland
# 1243     United States
# 1244    United Kingdom
# 1245         Australia
# 1246     United States
# 1247           Finland
# 1248     United States
# 1249     United States
# 1250     United States
# 1251      South Africa
# 1252     United States
# 1253     United States
# 1254    United Kingdom
# 1255     United States
# 1256     United States
# 1257     United States
# 1258     United States
# Name: Country, Length: 1259, dtype: object

# %%
country_state = df[['Country','state']]
country_state.head()
# Out:
#           Country state
# 0   United States    IL
# 1   United States    IN
# 2          Canada   NaN
# 3  United Kingdom   NaN
# 4   United States    TX

# %% [markdown]
# ## Extracting rows

# %%
df.iloc[0] # iloc should use integer: give the zero row of the dataframe
# Out:
# Timestamp                    2014-08-27 11:29:31
# Age                                           37
# Gender                                    Female
# Country                            United States
# state                                         IL
# self_employed                                NaN
# family_history                                No
# treatment                                    Yes
# work_interfere                             Often
# no_employees                                6-25
# remote_work                                   No
# tech_company                                 Yes
# benefits                                     Yes
# care_options                            Not sure
# wellness_program                              No
# seek_help                                    Yes
# anonymity                                    Yes
# leave                              Somewhat easy
# mental_health_consequence                     No
# phys_health_consequence                       No
# coworkers                           Some of them
# supervisor                                   Yes
# mental_health_interview                       No
# phys_health_interview                      Maybe
# mental_vs_physical                           Yes
# obs_consequence                               No
# comments                                     NaN
# Name: 0, dtype: object

# %%
df.loc[0] # give the row with the index value is zero!!!
# Out:
# Timestamp                    2014-08-27 11:29:31
# Age                                           37
# Gender                                    Female
# Country                            United States
# state                                         IL
# self_employed                                NaN
# family_history                                No
# treatment                                    Yes
# work_interfere                             Often
# no_employees                                6-25
# remote_work                                   No
# tech_company                                 Yes
# benefits                                     Yes
# care_options                            Not sure
# wellness_program                              No
# seek_help                                    Yes
# anonymity                                    Yes
# leave                              Somewhat easy
# mental_health_consequence                     No
# phys_health_consequence                       No
# coworkers                           Some of them
# supervisor                                   Yes
# mental_health_interview                       No
# phys_health_interview                      Maybe
# mental_vs_physical                           Yes
# obs_consequence                               No
# comments                                     NaN
# Name: 0, dtype: object

# %%
df_gender = df.set_index('Gender')
df_gender.head()
# Out:
#                   Timestamp  Age         Country state self_employed  \
# Gender
# Female  2014-08-27 11:29:31   37   United States    IL           NaN
# M       2014-08-27 11:29:37   44   United States    IN           NaN
# Male    2014-08-27 11:29:44   32          Canada   NaN           NaN
# Male    2014-08-27 11:29:46   31  United Kingdom   NaN           NaN
# Male    2014-08-27 11:30:22   31   United States    TX           NaN
#
#        family_history treatment work_interfere    no_employees remote_work  \
# Gender
# Female             No       Yes          Often            6-25          No
# M                  No        No         Rarely  More than 1000          No
# Male               No        No         Rarely            6-25          No
# Male              Yes       Yes          Often          26-100          No
# Male               No        No          Never         100-500         Yes
#
#          ...                  leave mental_health_consequence  \
# Gender   ...
# Female   ...          Somewhat easy                        No
# M        ...             Don't know                     Maybe
# Male     ...     Somewhat difficult                        No
# Male     ...     Somewhat difficult                       Yes
# Male     ...             Don't know                        No
#
#        phys_health_consequence     coworkers supervisor  \
# Gender
# Female                      No  Some of them        Yes
# M                           No            No         No
# Male                        No           Yes        Yes
# Male                       Yes  Some of them         No
# Male                        No  Some of them        Yes
#
#        mental_health_interview phys_health_interview mental_vs_physical  \
# Gender
# Female                      No                 Maybe                Yes
# M                           No                    No         Don't know
# Male                       Yes                   Yes                 No
# Male                     Maybe                 Maybe                 No
# Male                       Yes                   Yes         Don't know
#
#        obs_consequence comments
# Gender
# Female              No      NaN
# M                   No      NaN
# Male                No      NaN
# Male               Yes      NaN
# Male                No      NaN
#
# [5 rows x 26 columns]

# %%
df_gender.loc['Male'] # index can be different in python
# Out:
#                   Timestamp  Age         Country state self_employed  \
# Gender
# Male    2014-08-27 11:29:44   32          Canada   NaN           NaN
# Male    2014-08-27 11:29:46   31  United Kingdom   NaN           NaN
# Male    2014-08-27 11:30:22   31   United States    TX           NaN
# Male    2014-08-27 11:31:22   33   United States    TN           NaN
# Male    2014-08-27 11:32:43   23          Canada   NaN           NaN
# Male    2014-08-27 11:32:44   31   United States    OH           NaN
# Male    2014-08-27 11:33:26   36   United States    CT           NaN
# Male    2014-08-27 11:33:57   27          Canada   NaN           NaN
# Male    2014-08-27 11:34:20   23  United Kingdom   NaN           NaN
# Male    2014-08-27 11:34:37   32   United States    TN           NaN
# Male    2014-08-27 11:35:08   36          France   NaN           Yes
# Male    2014-08-27 11:35:12   29   United States    NY            No
# Male    2014-08-27 11:35:48   46   United States    MA            No
# Male    2014-08-27 11:36:24   41   United States    IA            No
# Male    2014-08-27 11:38:18   37  United Kingdom   NaN            No
# Male    2014-08-27 11:39:03   32  United Kingdom   NaN            No
# Male    2014-08-27 11:38:55   31   United States    PA           Yes
# Male    2014-08-27 11:39:36   42   United States    WA            No
# Male    2014-08-27 11:41:17   27   United States    NY            No
# Male    2014-08-27 11:41:37   29          Canada   NaN            No
# Male    2014-08-27 11:41:50   38        Portugal   NaN            No
# Male    2014-08-27 11:42:25   24  United Kingdom   NaN            No
# Male    2014-08-27 11:42:31   35   United States    MI            No
# Male    2014-08-27 11:43:07   27          Canada   NaN            No
# Male    2014-08-27 11:43:10   18     Netherlands   NaN            No
# Male    2014-08-27 11:43:22   30   United States    IN            No
# Male    2014-08-27 11:43:45   28  United Kingdom   NaN            No
# Male    2014-08-27 11:43:48   34   United States    TN            No
# Male    2014-08-27 11:45:32   33   United States    UT            No
# Male    2014-08-27 11:45:51   32   United States    TN            No
# ...                     ...  ...             ...   ...           ...
# Male    2015-02-21 04:41:28   32   United States    TX            No
# Male    2015-02-21 04:55:11   28       Australia   NaN            No
# Male    2015-02-21 05:34:27   31          Brazil   NaN           Yes
# Male    2015-02-21 05:55:13   24  United Kingdom   NaN            No
# Male    2015-02-21 05:55:17   34         Ireland   NaN            No
# Male    2015-02-21 06:19:41   34  United Kingdom   NaN            No
# Male    2015-02-21 08:21:36   23   United States    TX            No
# Male    2015-02-21 08:54:40   33  Czech Republic   NaN            No
# Male    2015-02-21 09:19:12   31     Philippines   NaN            No
# Male    2015-02-21 09:22:23   33   United States    FL            No
# Male    2015-02-21 09:30:14   27  United Kingdom   NaN            No
# Male    2015-02-21 09:48:13   38   United States    TX            No
# Male    2015-02-21 10:00:50   46   United States    CA            No
# Male    2015-02-21 17:19:18   39     Netherlands   NaN            No
# Male    2015-02-21 18:59:05   25   United States    MN            No
# Male    2015-02-22 02:40:32   39          Greece   NaN            No
# Male    2015-02-24 09:00:56   25  United Kingdom   NaN            No
# Male    2015-02-24 09:13:49   23  United Kingdom   NaN            No
# Male    2015-02-24 09:18:25   23          Canada   NaN            No
# Male    2015-02-24 10:32:32   60   United States    CA            No
# Male    2015-04-02 15:47:43   28   United States    TN            No
# Male    2015-04-11 14:35:22   31          Poland   NaN           Yes
# Male    2015-04-23 14:03:51   28         Ireland   NaN            No
# Male    2015-05-06 10:14:50   22       Australia   NaN            No
# Male    2015-05-06 16:55:58   32   United States    OR            No
# Male    2015-07-27 23:25:34   30   United States    CA           Yes
# Male    2015-08-17 09:38:35   36    South Africa   NaN            No
# Male    2015-08-25 19:59:38   36   United States    UT            No
# Male    2015-09-26 01:07:35   32   United States    IL            No
# Male    2016-02-01 23:04:31   25   United States    IL            No
#
#        family_history treatment work_interfere    no_employees remote_work  \
# Gender
# Male               No        No         Rarely            6-25          No
# Male              Yes       Yes          Often          26-100          No
# Male               No        No          Never         100-500         Yes
# Male              Yes        No      Sometimes            6-25          No
# Male               No        No          Never          26-100          No
# Male               No       Yes      Sometimes            6-25         Yes
# Male              Yes        No          Never        500-1000          No
# Male               No        No          Never            6-25          No
# Male               No       Yes      Sometimes          26-100         Yes
# Male               No       Yes      Sometimes            6-25          No
# Male              Yes        No            NaN            6-25         Yes
# Male              Yes       Yes      Sometimes         100-500          No
# Male               No       Yes          Often          26-100         Yes
# Male               No       Yes          Never  More than 1000          No
# Male               No        No      Sometimes            6-25          No
# Male               No        No          Never            6-25         Yes
# Male              Yes        No         Rarely             1-5         Yes
# Male              Yes       Yes      Sometimes          26-100         Yes
# Male               No       Yes         Rarely            6-25          No
# Male               No        No         Rarely             1-5          No
# Male               No        No            NaN         100-500          No
# Male               No       Yes      Sometimes            6-25          No
# Male               No        No            NaN  More than 1000         Yes
# Male              Yes       Yes      Sometimes             1-5          No
# Male               No        No          Often            6-25          No
# Male               No       Yes      Sometimes          26-100          No
# Male               No        No            NaN          26-100          No
# Male               No        No            NaN            6-25          No
# Male               No        No            NaN         100-500         Yes
# Male               No        No          Never             1-5         Yes
# ...               ...       ...            ...             ...         ...
# Male               No       Yes          Often          26-100         Yes
# Male               No       Yes          Often         100-500         Yes
# Male               No       Yes            NaN             1-5          No
# Male               No        No            NaN         100-500          No
# Male              Yes       Yes          Never             1-5         Yes
# Male              Yes        No          Often          26-100         Yes
# Male               No       Yes      Sometimes             1-5          No
# Male              Yes        No          Often         100-500          No
# Male               No        No      Sometimes  More than 1000          No
# Male               No       Yes          Often          26-100         Yes
# Male               No        No         Rarely  More than 1000         Yes
# Male               No       Yes      Sometimes  More than 1000         Yes
# Male              Yes       Yes          Often          26-100          No
# Male               No        No            NaN  More than 1000          No
# Male              Yes       Yes      Sometimes          26-100          No
# Male               No        No            NaN            6-25         Yes
# Male              Yes       Yes      Sometimes  More than 1000          No
# Male               No       Yes         Rarely            6-25          No
# Male               No       Yes          Often          26-100          No
# Male               No       Yes          Often  More than 1000         Yes
# Male              Yes       Yes          Often  More than 1000          No
# Male               No       Yes          Often            6-25         Yes
# Male               No       Yes         Rarely          26-100          No
# Male              Yes       Yes          Often         100-500          No
# Male               No        No          Never         100-500          No
# Male              Yes       Yes          Often          26-100          No
# Male              Yes       Yes          Often         100-500          No
# Male              Yes        No         Rarely  More than 1000          No
# Male              Yes       Yes          Often          26-100         Yes
# Male              Yes       Yes      Sometimes          26-100          No
#
#                               ...                                       leave  \
# Gender                        ...
# Male                          ...                          Somewhat difficult
# Male                          ...                          Somewhat difficult
# Male                          ...                                  Don't know
# Male                          ...                                  Don't know
# Male                          ...                                  Don't know
# Male                          ...                                  Don't know
# Male                          ...                                  Don't know
# Male                          ...                               Somewhat easy
# Male                          ...                                   Very easy
# Male                          ...                                  Don't know
# Male                          ...                               Somewhat easy
# Male                          ...                          Somewhat difficult
# Male                          ...                                  Don't know
# Male                          ...                                  Don't know
# Male                          ...                              Very difficult
# Male                          ...                                  Don't know
# Male                          ...                          Somewhat difficult
# Male                          ...                                   Very easy
# Male                          ...                                   Very easy
# Male                          ...                                   Very easy
# Male                          ...                               Somewhat easy
# Male                          ...                                  Don't know
# Male                          ...                          Somewhat difficult
# Male                          ...                              Very difficult
# Male                          ...                          Somewhat difficult
# Male                          ...                                  Don't know
# Male                          ...                                  Don't know
# Male                          ...                                  Don't know
# Male                          ...                                  Don't know
# Male                          ...                                  Don't know
# ...                           ...                                         ...
# Male                          ...                              Very difficult
# Male                          ...                                  Don't know
# Male                          ...                                  Don't know
# Male                          ...                               Somewhat easy
# Male                          ...                                  Don't know
# Male                          ...                               Somewhat easy
# Male                          ...                                   Very easy
# Male                          ...                               Somewhat easy
# Male                          ...                              Very difficult
# Male                          ...                                  Don't know
# Male                          ...                                  Don't know
# Male                          ...                                   Very easy
# Male                          ...                                  Don't know
# Male                          ...                               Somewhat easy
# Male                          ...                               Somewhat easy
# Male                          ...                                  Don't know
# Male                          ...                                   Very easy
# Male                          ...                                  Don't know
# Male                          ...                                  Don't know
# Male                          ...                               Somewhat easy
# Male                          ...                               Somewhat easy
# Male                          ...                               Somewhat easy
# Male                          ...                                  Don't know
# Male                          ...                                  Don't know
# Male                          ...                               Somewhat easy
# Male                          ...                                  Don't know
# Male                          ...                               Somewhat easy
# Male                          ...                               Somewhat easy
# Male                          ...                          Somewhat difficult
# Male                          ...                                  Don't know
#
#        mental_health_consequence phys_health_consequence     coworkers  \
# Gender
# Male                          No                      No           Yes
# Male                         Yes                     Yes  Some of them
# Male                          No                      No  Some of them
# Male                          No                      No           Yes
# Male                          No                      No           Yes
# Male                          No                      No  Some of them
# Male                          No                      No           Yes
# Male                          No                      No  Some of them
# Male                       Maybe                      No  Some of them
# Male                       Maybe                      No  Some of them
# Male                          No                      No  Some of them
# Male                       Maybe                      No  Some of them
# Male                       Maybe                      No  Some of them
# Male                       Maybe                      No            No
# Male                         Yes                   Maybe  Some of them
# Male                         Yes                     Yes  Some of them
# Male                         Yes                      No            No
# Male                       Maybe                      No  Some of them
# Male                          No                      No           Yes
# Male                         Yes                   Maybe  Some of them
# Male                       Maybe                      No  Some of them
# Male                       Maybe                   Maybe  Some of them
# Male                         Yes                     Yes  Some of them
# Male                       Maybe                      No  Some of them
# Male                         Yes                   Maybe            No
# Male                          No                      No            No
# Male                          No                   Maybe  Some of them
# Male                          No                      No           Yes
# Male                          No                      No  Some of them
# Male                       Maybe                      No  Some of them
# ...                          ...                     ...           ...
# Male                         Yes                   Maybe  Some of them
# Male                         Yes                      No            No
# Male                          No                      No           Yes
# Male                       Maybe                   Maybe  Some of them
# Male                       Maybe                      No  Some of them
# Male                       Maybe                      No  Some of them
# Male                       Maybe                   Maybe  Some of them
# Male                          No                      No  Some of them
# Male                         Yes                     Yes  Some of them
# Male                       Maybe                      No  Some of them
# Male                          No                      No  Some of them
# Male                          No                      No           Yes
# Male                       Maybe                      No  Some of them
# Male                       Maybe                   Maybe            No
# Male                         Yes                      No  Some of them
# Male                         Yes                      No            No
# Male                          No                      No           Yes
# Male                          No                      No           Yes
# Male                       Maybe                      No           Yes
# Male                       Maybe                   Maybe  Some of them
# Male                         Yes                   Maybe  Some of them
# Male                       Maybe                      No  Some of them
# Male                       Maybe                      No            No
# Male                       Maybe                   Maybe            No
# Male                          No                      No            No
# Male                          No                      No  Some of them
# Male                          No                      No  Some of them
# Male                       Maybe                   Maybe  Some of them
# Male                          No                      No  Some of them
# Male                       Maybe                      No  Some of them
#
#           supervisor mental_health_interview phys_health_interview  \
# Gender
# Male             Yes                     Yes                   Yes
# Male              No                   Maybe                 Maybe
# Male             Yes                     Yes                   Yes
# Male             Yes                      No                 Maybe
# Male             Yes                   Maybe                 Maybe
# Male             Yes                      No                    No
# Male             Yes                      No                    No
# Male    Some of them                   Maybe                   Yes
# Male              No                   Maybe                 Maybe
# Male             Yes                      No                    No
# Male    Some of them                   Maybe                 Maybe
# Male    Some of them                      No                    No
# Male             Yes                      No                 Maybe
# Male              No                      No                   Yes
# Male              No                      No                 Maybe
# Male    Some of them                      No                 Maybe
# Male              No                      No                    No
# Male    Some of them                   Maybe                   Yes
# Male             Yes                   Maybe                 Maybe
# Male              No                      No                    No
# Male    Some of them                      No                 Maybe
# Male              No                      No                   Yes
# Male              No                      No                 Maybe
# Male              No                      No                    No
# Male    Some of them                      No                    No
# Male              No                      No                 Maybe
# Male             Yes                   Maybe                   Yes
# Male             Yes                   Maybe                   Yes
# Male             Yes                   Maybe                 Maybe
# Male             Yes                      No                    No
# ...              ...                     ...                   ...
# Male              No                      No                    No
# Male              No                      No                 Maybe
# Male             Yes                      No                 Maybe
# Male             Yes                      No                 Maybe
# Male             Yes                      No                    No
# Male             Yes                   Maybe                   Yes
# Male             Yes                      No                    No
# Male             Yes                   Maybe                 Maybe
# Male              No                      No                 Maybe
# Male              No                      No                 Maybe
# Male             Yes                      No                    No
# Male             Yes                      No                    No
# Male              No                      No                    No
# Male    Some of them                      No                    No
# Male    Some of them                      No                 Maybe
# Male              No                      No                    No
# Male             Yes                     Yes                   Yes
# Male             Yes                      No                 Maybe
# Male    Some of them                      No                    No
# Male              No                      No                 Maybe
# Male             Yes                      No                    No
# Male              No                      No                    No
# Male              No                      No                 Maybe
# Male             Yes                      No                 Maybe
# Male    Some of them                   Maybe                   Yes
# Male             Yes                   Maybe                 Maybe
# Male             Yes                      No                   Yes
# Male    Some of them                      No                    No
# Male             Yes                      No                    No
# Male              No                      No                    No
#
#        mental_vs_physical obs_consequence  \
# Gender
# Male                   No              No
# Male                   No             Yes
# Male           Don't know              No
# Male           Don't know              No
# Male                  Yes              No
# Male           Don't know              No
# Male           Don't know              No
# Male                  Yes              No
# Male                   No              No
# Male                   No              No
# Male           Don't know              No
# Male                   No              No
# Male                   No              No
# Male           Don't know              No
# Male                   No              No
# Male                   No              No
# Male                   No             Yes
# Male           Don't know              No
# Male           Don't know              No
# Male           Don't know              No
# Male                   No              No
# Male                   No             Yes
# Male           Don't know              No
# Male                  Yes              No
# Male                   No              No
# Male           Don't know              No
# Male           Don't know              No
# Male           Don't know              No
# Male           Don't know              No
# Male           Don't know              No
# ...                   ...             ...
# Male           Don't know              No
# Male                   No              No
# Male           Don't know              No
# Male           Don't know              No
# Male           Don't know              No
# Male                  Yes              No
# Male                   No              No
# Male           Don't know             Yes
# Male                   No             Yes
# Male           Don't know              No
# Male           Don't know              No
# Male           Don't know              No
# Male                   No              No
# Male                  Yes              No
# Male           Don't know              No
# Male           Don't know              No
# Male                  Yes              No
# Male           Don't know              No
# Male           Don't know              No
# Male           Don't know              No
# Male                   No             Yes
# Male           Don't know              No
# Male           Don't know              No
# Male           Don't know             Yes
# Male           Don't know              No
# Male                  Yes              No
# Male                  Yes              No
# Male           Don't know              No
# Male                  Yes              No
# Male           Don't know              No
#
#                                                  comments
# Gender
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male    I'm not on my company's health insurance which...
# Male                                                  NaN
# Male    My company does provide healthcare but not to ...
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male    I selected my current employer based on its po...
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# ...                                                   ...
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male    I openly discuss my mental health struggles. I...
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male    I work at a large university with a track reco...
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male    In australia all organisations of a certain si...
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
# Male                                                  NaN
#
# [615 rows x 26 columns]

# %%
df.iloc['Gender'] # generates error
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-43-80e648bff291> in <module>()
# ----> 1 df.iloc['Gender'] # generates error
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1371
#    1372             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1373             return self._getitem_axis(maybe_callable, axis=axis)
#    1374
#    1375     def _is_scalar_access(self, key):
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_axis(self, key, axis)
#    1821         # a single integer
#    1822         else:
# -> 1823             key = self._convert_scalar_indexer(key, axis)
#    1824
#    1825             if not is_integer(key):
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in _convert_scalar_indexer(self, key, axis)
#     254         ax = self.obj._get_axis(min(axis, self.ndim - 1))
#     255         # a scalar
# --> 256         return ax._convert_scalar_indexer(key, kind=self.name)
#     257
#     258     def _convert_slice_indexer(self, key, axis):
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/indexes/numeric.pyc in _convert_scalar_indexer(self, key, kind)
#     166             key = self._maybe_cast_indexer(key)
#     167         return (super(Int64Index, self)
# --> 168                 ._convert_scalar_indexer(key, kind=kind))
#     169
#     170     def _wrap_joined_index(self, joined, other):
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in _convert_scalar_indexer(self, key, kind)
#    1363
#    1364         if kind == 'iloc':
# -> 1365             return self._validate_indexer('positional', key, kind)
#    1366
#    1367         if len(self) and not isinstance(self, ABCMultiIndex,):
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in _validate_indexer(self, form, key, kind)
#    3493             pass
#    3494         elif kind in ['iloc', 'getitem']:
# -> 3495             self._invalid_indexer(form, key)
#    3496         return key
#    3497
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in _invalid_indexer(self, form, key)
#    1574                         "indexers [{key}] of {kind}".format(
#    1575                             form=form, klass=type(self), key=key,
# -> 1576                             kind=type(key)))
#    1577
#    1578     def get_duplicates(self):
#
# TypeError: cannot do positional indexing on <class 'pandas.core.indexes.range.RangeIndex'> with these indexers [Gender] of <type 'str'>

# %%
df.iloc[0]
# Out:
# Timestamp                    2014-08-27 11:29:31
# Age                                           37
# Gender                                    Female
# Country                            United States
# state                                         IL
# self_employed                                NaN
# family_history                                No
# treatment                                    Yes
# work_interfere                             Often
# no_employees                                6-25
# remote_work                                   No
# tech_company                                 Yes
# benefits                                     Yes
# care_options                            Not sure
# wellness_program                              No
# seek_help                                    Yes
# anonymity                                    Yes
# leave                              Somewhat easy
# mental_health_consequence                     No
# phys_health_consequence                       No
# coworkers                           Some of them
# supervisor                                   Yes
# mental_health_interview                       No
# phys_health_interview                      Maybe
# mental_vs_physical                           Yes
# obs_consequence                               No
# comments                                     NaN
# Name: 0, dtype: object

# %% [markdown]
# ## Sorting
# You can use either sort_values() or sort_index():

# %%
df_sorted = df.sort_values('Age') # sort_values is increasing series
df_sorted.head(10)
# Out:
#                 Timestamp   Age              Gender         Country state  \
# 715   2014-08-28 10:07:53 -1726                male  United Kingdom   NaN
# 143   2014-08-27 12:39:14   -29                Male   United States    MN
# 1127  2014-08-30 20:55:11    -1                   p   United States    AL
# 734   2014-08-28 10:35:55     5                Male   United States    OH
# 989   2014-08-29 09:10:58     8  A little about you    Bahamas, The    IL
# 1090  2014-08-29 17:26:15    11                male   United States    OH
# 282   2014-08-27 14:10:15    18                male   United States    TX
# 287   2014-08-27 14:11:55    18                Male   United States    WA
# 43    2014-08-27 11:43:10    18                Male     Netherlands   NaN
# 482   2014-08-27 16:19:05    18              Female  United Kingdom   NaN
#
#      self_employed family_history treatment work_interfere    no_employees  \
# 715             No             No       Yes      Sometimes          26-100
# 143             No             No        No            NaN  More than 1000
# 1127           Yes            Yes       Yes          Often             1-5
# 734             No             No        No            NaN         100-500
# 989            Yes            Yes       Yes          Often             1-5
# 1090           Yes             No        No          Never             1-5
# 282             No             No       Yes      Sometimes            6-25
# 287             No             No        No          Never          26-100
# 43              No             No        No          Often            6-25
# 482             No            Yes       Yes      Sometimes             1-5
#
#                             ...                                       leave  \
# 715                         ...                          Somewhat difficult
# 143                         ...                                  Don't know
# 1127                        ...                                   Very easy
# 734                         ...                               Somewhat easy
# 989                         ...                                   Very easy
# 1090                        ...                                   Very easy
# 282                         ...                                  Don't know
# 287                         ...                                   Very easy
# 43                          ...                          Somewhat difficult
# 482                         ...                                  Don't know
#
#      mental_health_consequence phys_health_consequence     coworkers  \
# 715                        Yes                      No            No
# 143                         No                      No  Some of them
# 1127                       Yes                     Yes           Yes
# 734                         No                      No           Yes
# 989                        Yes                     Yes           Yes
# 1090                        No                      No  Some of them
# 282                        Yes                      No            No
# 287                         No                      No  Some of them
# 43                         Yes                   Maybe            No
# 482                      Maybe                   Maybe  Some of them
#
#         supervisor mental_health_interview phys_health_interview  \
# 715             No                      No                 Maybe
# 143            Yes                      No                    No
# 1127           Yes                     Yes                   Yes
# 734            Yes                      No                    No
# 989            Yes                     Yes                   Yes
# 1090  Some of them                      No                 Maybe
# 282             No                      No                 Maybe
# 287   Some of them                      No                 Maybe
# 43    Some of them                      No                    No
# 482   Some of them                   Maybe                 Maybe
#
#      mental_vs_physical obs_consequence  \
# 715          Don't know              No
# 143          Don't know              No
# 1127                Yes             Yes
# 734                 Yes              No
# 989                 Yes             Yes
# 1090                Yes              No
# 282          Don't know              No
# 287                 Yes              No
# 43                   No              No
# 482          Don't know              No
#
#                                                comments
# 715                                                 NaN
# 143                                                 NaN
# 1127                                 password: testered
# 734   We had a developer suffer from depression and ...
# 989
# 1090                                                NaN
# 282                                                 NaN
# 287                                                 NaN
# 43                                                  NaN
# 482                               I don't have a job :D
#
# [10 rows x 27 columns]

# %% [markdown]
# ## Filtering using Boolean Masking

# %%
df.Age # same as df['Age'] if there is black in column name: canot use df.Country education
# Out:
# 0       37
# 1       44
# 2       32
# 3       31
# 4       31
# 5       33
# 6       35
# 7       39
# 8       42
# 9       23
# 10      31
# 11      29
# 12      42
# 13      36
# 14      27
# 15      29
# 16      23
# 17      32
# 18      46
# 19      36
# 20      29
# 21      31
# 22      46
# 23      41
# 24      33
# 25      35
# 26      33
# 27      35
# 28      34
# 29      37
#         ..
# 1229    39
# 1230    23
# 1231    24
# 1232    25
# 1233    23
# 1234    24
# 1235    23
# 1236    60
# 1237    28
# 1238    28
# 1239    30
# 1240    31
# 1241    31
# 1242    28
# 1243    43
# 1244    32
# 1245    22
# 1246    32
# 1247    36
# 1248    41
# 1249    30
# 1250    30
# 1251    36
# 1252    29
# 1253    36
# 1254    26
# 1255    32
# 1256    34
# 1257    46
# 1258    25
# Name: Age, Length: 1259, dtype: int64

# %%
df['Age'] > 0
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9       True
# 10      True
# 11      True
# 12      True
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True
# 21      True
# 22      True
# 23      True
# 24      True
# 25      True
# 26      True
# 27      True
# 28      True
# 29      True
#         ...
# 1229    True
# 1230    True
# 1231    True
# 1232    True
# 1233    True
# 1234    True
# 1235    True
# 1236    True
# 1237    True
# 1238    True
# 1239    True
# 1240    True
# 1241    True
# 1242    True
# 1243    True
# 1244    True
# 1245    True
# 1246    True
# 1247    True
# 1248    True
# 1249    True
# 1250    True
# 1251    True
# 1252    True
# 1253    True
# 1254    True
# 1255    True
# 1256    True
# 1257    True
# 1258    True
# Name: Age, Length: 1259, dtype: bool

# %%
df[df['Age'] > 0]
# Out:
#                 Timestamp  Age  \
# 0     2014-08-27 11:29:31   37
# 1     2014-08-27 11:29:37   44
# 2     2014-08-27 11:29:44   32
# 3     2014-08-27 11:29:46   31
# 4     2014-08-27 11:30:22   31
# 5     2014-08-27 11:31:22   33
# 6     2014-08-27 11:31:50   35
# 7     2014-08-27 11:32:05   39
# 8     2014-08-27 11:32:39   42
# 9     2014-08-27 11:32:43   23
# 10    2014-08-27 11:32:44   31
# 11    2014-08-27 11:32:49   29
# 12    2014-08-27 11:33:23   42
# 13    2014-08-27 11:33:26   36
# 14    2014-08-27 11:33:57   27
# 15    2014-08-27 11:34:00   29
# 16    2014-08-27 11:34:20   23
# 17    2014-08-27 11:34:37   32
# 18    2014-08-27 11:34:53   46
# 19    2014-08-27 11:35:08   36
# 20    2014-08-27 11:35:12   29
# 21    2014-08-27 11:35:24   31
# 22    2014-08-27 11:35:48   46
# 23    2014-08-27 11:36:24   41
# 24    2014-08-27 11:36:48   33
# 25    2014-08-27 11:37:08   35
# 26    2014-08-27 11:37:23   33
# 27    2014-08-27 11:37:59   35
# 28    2014-08-27 11:38:12   34
# 29    2014-08-27 11:38:18   37
# ...                   ...  ...
# 1229  2015-02-22 02:40:32   39
# 1230  2015-02-24 08:54:35   23
# 1231  2015-02-24 08:58:08   24
# 1232  2015-02-24 09:00:56   25
# 1233  2015-02-24 09:13:49   23
# 1234  2015-02-24 09:15:13   24
# 1235  2015-02-24 09:18:25   23
# 1236  2015-02-24 10:32:32   60
# 1237  2015-02-26 05:44:16   28
# 1238  2015-04-02 15:47:43   28
# 1239  2015-04-04 11:22:05   30
# 1240  2015-04-06 14:58:29   31
# 1241  2015-04-11 14:35:22   31
# 1242  2015-04-23 14:03:51   28
# 1243  2015-05-05 14:22:18   43
# 1244  2015-05-05 15:16:25   32
# 1245  2015-05-06 10:14:50   22
# 1246  2015-05-06 16:55:58   32
# 1247  2015-05-07 10:08:50   36
# 1248  2015-06-25 12:24:31   41
# 1249  2015-07-22 18:57:54   30
# 1250  2015-07-27 23:25:34   30
# 1251  2015-08-17 09:38:35   36
# 1252  2015-08-20 16:52:09   29
# 1253  2015-08-25 19:59:38   36
# 1254  2015-09-12 11:17:21   26
# 1255  2015-09-26 01:07:35   32
# 1256  2015-11-07 12:36:58   34
# 1257  2015-11-30 21:25:06   46
# 1258  2016-02-01 23:04:31   25
#
#                                               Gender         Country state  \
# 0                                             Female   United States    IL
# 1                                                  M   United States    IN
# 2                                               Male          Canada   NaN
# 3                                               Male  United Kingdom   NaN
# 4                                               Male   United States    TX
# 5                                               Male   United States    TN
# 6                                             Female   United States    MI
# 7                                                  M          Canada   NaN
# 8                                             Female   United States    IL
# 9                                               Male          Canada   NaN
# 10                                              Male   United States    OH
# 11                                              male        Bulgaria   NaN
# 12                                            female   United States    CA
# 13                                              Male   United States    CT
# 14                                              Male          Canada   NaN
# 15                                            female   United States    IL
# 16                                              Male  United Kingdom   NaN
# 17                                              Male   United States    TN
# 18                                              male   United States    MD
# 19                                              Male          France   NaN
# 20                                              Male   United States    NY
# 21                                              male   United States    NC
# 22                                              Male   United States    MA
# 23                                              Male   United States    IA
# 24                                              male   United States    CA
# 25                                              male   United States    TN
# 26                                              male   United States    TN
# 27                                            Female   United States    CA
# 28                                              male   United States    OH
# 29                                              Male  United Kingdom   NaN
# ...                                              ...             ...   ...
# 1229                                            Male          Greece   NaN
# 1230                                          Female  United Kingdom   NaN
# 1231                                         Cis Man  United Kingdom   NaN
# 1232                                            Male  United Kingdom   NaN
# 1233                                            Male  United Kingdom   NaN
# 1234  ostensibly male, unsure what that really means  United Kingdom   NaN
# 1235                                            Male          Canada   NaN
# 1236                                            Male   United States    CA
# 1237                                            male         Ireland   NaN
# 1238                                            Male   United States    TN
# 1239                                            male     Netherlands   NaN
# 1240                                            male         Germany   NaN
# 1241                                            Male          Poland   NaN
# 1242                                            Male         Ireland   NaN
# 1243                                               f   United States    FL
# 1244                                          female  United Kingdom   NaN
# 1245                                            Male       Australia   NaN
# 1246                                            Male   United States    OR
# 1247                                            male         Finland   NaN
# 1248                                          Female   United States    WA
# 1249                                               M   United States    CA
# 1250                                            Male   United States    CA
# 1251                                            Male    South Africa   NaN
# 1252                                            male   United States    NC
# 1253                                            Male   United States    UT
# 1254                                            male  United Kingdom   NaN
# 1255                                            Male   United States    IL
# 1256                                            male   United States    CA
# 1257                                               f   United States    NC
# 1258                                            Male   United States    IL
#
#      self_employed family_history treatment work_interfere    no_employees  \
# 0              NaN             No       Yes          Often            6-25
# 1              NaN             No        No         Rarely  More than 1000
# 2              NaN             No        No         Rarely            6-25
# 3              NaN            Yes       Yes          Often          26-100
# 4              NaN             No        No          Never         100-500
# 5              NaN            Yes        No      Sometimes            6-25
# 6              NaN            Yes       Yes      Sometimes             1-5
# 7              NaN             No        No          Never             1-5
# 8              NaN            Yes       Yes      Sometimes         100-500
# 9              NaN             No        No          Never          26-100
# 10             NaN             No       Yes      Sometimes            6-25
# 11             NaN             No        No          Never         100-500
# 12             NaN            Yes       Yes      Sometimes          26-100
# 13             NaN            Yes        No          Never        500-1000
# 14             NaN             No        No          Never            6-25
# 15             NaN            Yes       Yes         Rarely          26-100
# 16             NaN             No       Yes      Sometimes          26-100
# 17             NaN             No       Yes      Sometimes            6-25
# 18             Yes            Yes        No      Sometimes             1-5
# 19             Yes            Yes        No            NaN            6-25
# 20              No            Yes       Yes      Sometimes         100-500
# 21             Yes             No        No          Never             1-5
# 22              No             No       Yes          Often          26-100
# 23              No             No       Yes          Never  More than 1000
# 24              No            Yes       Yes         Rarely          26-100
# 25              No            Yes       Yes      Sometimes  More than 1000
# 26              No             No        No            NaN             1-5
# 27              No            Yes       Yes         Rarely            6-25
# 28              No             No       Yes      Sometimes          26-100
# 29              No             No        No      Sometimes            6-25
# ...            ...            ...       ...            ...             ...
# 1229            No             No        No            NaN            6-25
# 1230            No            Yes       Yes      Sometimes            6-25
# 1231           Yes             No       Yes      Sometimes            6-25
# 1232            No            Yes       Yes      Sometimes  More than 1000
# 1233            No             No       Yes         Rarely            6-25
# 1234            No             No       Yes      Sometimes            6-25
# 1235            No             No       Yes          Often          26-100
# 1236            No             No       Yes          Often  More than 1000
# 1237            No             No        No      Sometimes          26-100
# 1238            No            Yes       Yes          Often  More than 1000
# 1239            No             No        No      Sometimes        500-1000
# 1240            No            Yes       Yes      Sometimes         100-500
# 1241           Yes             No       Yes          Often            6-25
# 1242            No             No       Yes         Rarely          26-100
# 1243            No            Yes       Yes         Rarely  More than 1000
# 1244            No             No        No            NaN  More than 1000
# 1245            No            Yes       Yes          Often         100-500
# 1246            No             No        No          Never         100-500
# 1247            No             No       Yes          Often            6-25
# 1248            No            Yes       Yes      Sometimes          26-100
# 1249            No            Yes       Yes      Sometimes          26-100
# 1250           Yes            Yes       Yes          Often          26-100
# 1251            No            Yes       Yes          Often         100-500
# 1252            No            Yes       Yes      Sometimes         100-500
# 1253            No            Yes        No         Rarely  More than 1000
# 1254            No             No       Yes            NaN          26-100
# 1255            No            Yes       Yes          Often          26-100
# 1256            No            Yes       Yes      Sometimes  More than 1000
# 1257            No             No        No            NaN         100-500
# 1258            No            Yes       Yes      Sometimes          26-100
#
#                             ...                                       leave  \
# 0                           ...                               Somewhat easy
# 1                           ...                                  Don't know
# 2                           ...                          Somewhat difficult
# 3                           ...                          Somewhat difficult
# 4                           ...                                  Don't know
# 5                           ...                                  Don't know
# 6                           ...                          Somewhat difficult
# 7                           ...                                  Don't know
# 8                           ...                              Very difficult
# 9                           ...                                  Don't know
# 10                          ...                                  Don't know
# 11                          ...                                  Don't know
# 12                          ...                          Somewhat difficult
# 13                          ...                                  Don't know
# 14                          ...                               Somewhat easy
# 15                          ...                               Somewhat easy
# 16                          ...                                   Very easy
# 17                          ...                                  Don't know
# 18                          ...                                   Very easy
# 19                          ...                               Somewhat easy
# 20                          ...                          Somewhat difficult
# 21                          ...                          Somewhat difficult
# 22                          ...                                  Don't know
# 23                          ...                                  Don't know
# 24                          ...                                  Don't know
# 25                          ...                                   Very easy
# 26                          ...                                  Don't know
# 27                          ...                                  Don't know
# 28                          ...                          Somewhat difficult
# 29                          ...                              Very difficult
# ...                         ...                                         ...
# 1229                        ...                                  Don't know
# 1230                        ...                                   Very easy
# 1231                        ...                                  Don't know
# 1232                        ...                                   Very easy
# 1233                        ...                                  Don't know
# 1234                        ...                                  Don't know
# 1235                        ...                                  Don't know
# 1236                        ...                               Somewhat easy
# 1237                        ...                                  Don't know
# 1238                        ...                               Somewhat easy
# 1239                        ...                                  Don't know
# 1240                        ...                               Somewhat easy
# 1241                        ...                               Somewhat easy
# 1242                        ...                                  Don't know
# 1243                        ...                                  Don't know
# 1244                        ...                                  Don't know
# 1245                        ...                                  Don't know
# 1246                        ...                               Somewhat easy
# 1247                        ...                              Very difficult
# 1248                        ...                                  Don't know
# 1249                        ...                                   Very easy
# 1250                        ...                                  Don't know
# 1251                        ...                               Somewhat easy
# 1252                        ...                                  Don't know
# 1253                        ...                               Somewhat easy
# 1254                        ...                               Somewhat easy
# 1255                        ...                          Somewhat difficult
# 1256                        ...                          Somewhat difficult
# 1257                        ...                                  Don't know
# 1258                        ...                                  Don't know
#
#      mental_health_consequence phys_health_consequence     coworkers  \
# 0                           No                      No  Some of them
# 1                        Maybe                      No            No
# 2                           No                      No           Yes
# 3                          Yes                     Yes  Some of them
# 4                           No                      No  Some of them
# 5                           No                      No           Yes
# 6                        Maybe                   Maybe  Some of them
# 7                           No                      No            No
# 8                        Maybe                      No           Yes
# 9                           No                      No           Yes
# 10                          No                      No  Some of them
# 11                          No                      No           Yes
# 12                         Yes                     Yes           Yes
# 13                          No                      No           Yes
# 14                          No                      No  Some of them
# 15                          No                      No           Yes
# 16                       Maybe                      No  Some of them
# 17                       Maybe                      No  Some of them
# 18                          No                      No           Yes
# 19                          No                      No  Some of them
# 20                       Maybe                      No  Some of them
# 21                          No                      No  Some of them
# 22                       Maybe                      No  Some of them
# 23                       Maybe                      No            No
# 24                          No                      No           Yes
# 25                         Yes                      No  Some of them
# 26                       Maybe                   Maybe  Some of them
# 27                          No                      No           Yes
# 28                          No                      No  Some of them
# 29                         Yes                   Maybe  Some of them
# ...                        ...                     ...           ...
# 1229                       Yes                      No            No
# 1230                        No                      No           Yes
# 1231                     Maybe                   Maybe  Some of them
# 1232                        No                      No           Yes
# 1233                        No                      No           Yes
# 1234                       Yes                   Maybe            No
# 1235                     Maybe                      No           Yes
# 1236                     Maybe                   Maybe  Some of them
# 1237                       Yes                   Maybe            No
# 1238                       Yes                   Maybe  Some of them
# 1239                     Maybe                      No           Yes
# 1240                        No                      No  Some of them
# 1241                     Maybe                      No  Some of them
# 1242                     Maybe                      No            No
# 1243                        No                      No  Some of them
# 1244                     Maybe                      No  Some of them
# 1245                     Maybe                   Maybe            No
# 1246                        No                      No            No
# 1247                       Yes                      No  Some of them
# 1248                       Yes                   Maybe            No
# 1249                        No                      No           Yes
# 1250                        No                      No  Some of them
# 1251                        No                      No  Some of them
# 1252                       Yes                      No  Some of them
# 1253                     Maybe                   Maybe  Some of them
# 1254                        No                      No  Some of them
# 1255                        No                      No  Some of them
# 1256                       Yes                     Yes            No
# 1257                       Yes                      No            No
# 1258                     Maybe                      No  Some of them
#
#         supervisor mental_health_interview phys_health_interview  \
# 0              Yes                      No                 Maybe
# 1               No                      No                    No
# 2              Yes                     Yes                   Yes
# 3               No                   Maybe                 Maybe
# 4              Yes                     Yes                   Yes
# 5              Yes                      No                 Maybe
# 6               No                      No                    No
# 7               No                      No                    No
# 8              Yes                      No                 Maybe
# 9              Yes                   Maybe                 Maybe
# 10             Yes                      No                    No
# 11             Yes                     Yes                   Yes
# 12             Yes                   Maybe                 Maybe
# 13             Yes                      No                    No
# 14    Some of them                   Maybe                   Yes
# 15    Some of them                   Maybe                 Maybe
# 16              No                   Maybe                 Maybe
# 17             Yes                      No                    No
# 18             Yes                      No                   Yes
# 19    Some of them                   Maybe                 Maybe
# 20    Some of them                      No                    No
# 21    Some of them                      No                 Maybe
# 22             Yes                      No                 Maybe
# 23              No                      No                   Yes
# 24             Yes                      No                   Yes
# 25             Yes                      No                   Yes
# 26              No                      No                    No
# 27             Yes                   Maybe                 Maybe
# 28              No                      No                    No
# 29              No                      No                 Maybe
# ...            ...                     ...                   ...
# 1229            No                      No                    No
# 1230           Yes                   Maybe                 Maybe
# 1231  Some of them                      No                 Maybe
# 1232           Yes                     Yes                   Yes
# 1233           Yes                      No                 Maybe
# 1234            No                      No                 Maybe
# 1235  Some of them                      No                    No
# 1236            No                      No                 Maybe
# 1237            No                      No                    No
# 1238           Yes                      No                    No
# 1239           Yes                   Maybe                   Yes
# 1240            No                      No                    No
# 1241            No                      No                    No
# 1242            No                      No                 Maybe
# 1243           Yes                      No                    No
# 1244           Yes                      No                   Yes
# 1245           Yes                      No                 Maybe
# 1246  Some of them                   Maybe                   Yes
# 1247            No                      No                 Maybe
# 1248            No                      No                    No
# 1249           Yes                   Maybe                 Maybe
# 1250           Yes                   Maybe                 Maybe
# 1251           Yes                      No                   Yes
# 1252            No                      No                 Maybe
# 1253  Some of them                      No                    No
# 1254  Some of them                      No                    No
# 1255           Yes                      No                    No
# 1256            No                      No                    No
# 1257            No                      No                    No
# 1258            No                      No                    No
#
#      mental_vs_physical obs_consequence  \
# 0                   Yes              No
# 1            Don't know              No
# 2                    No              No
# 3                    No             Yes
# 4            Don't know              No
# 5            Don't know              No
# 6            Don't know              No
# 7                    No              No
# 8                    No              No
# 9                   Yes              No
# 10           Don't know              No
# 11           Don't know              No
# 12                   No             Yes
# 13           Don't know              No
# 14                  Yes              No
# 15           Don't know              No
# 16                   No              No
# 17                   No              No
# 18                  Yes             Yes
# 19           Don't know              No
# 20                   No              No
# 21                  Yes              No
# 22                   No              No
# 23           Don't know              No
# 24           Don't know              No
# 25                   No              No
# 26           Don't know              No
# 27                  Yes              No
# 28                   No              No
# 29                   No              No
# ...                 ...             ...
# 1229         Don't know              No
# 1230                Yes              No
# 1231         Don't know             Yes
# 1232                Yes              No
# 1233         Don't know              No
# 1234         Don't know              No
# 1235         Don't know              No
# 1236         Don't know              No
# 1237                 No             Yes
# 1238                 No             Yes
# 1239         Don't know              No
# 1240         Don't know              No
# 1241         Don't know              No
# 1242         Don't know              No
# 1243         Don't know              No
# 1244                 No              No
# 1245         Don't know             Yes
# 1246         Don't know              No
# 1247         Don't know             Yes
# 1248         Don't know              No
# 1249                Yes              No
# 1250                Yes              No
# 1251                Yes              No
# 1252                 No              No
# 1253         Don't know              No
# 1254         Don't know              No
# 1255                Yes              No
# 1256                 No              No
# 1257                 No              No
# 1258         Don't know              No
#
#                                                comments
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13    I'm not on my company's health insurance which...
# 14                                                  NaN
# 15    I have chronic low-level neurological issues t...
# 16    My company does provide healthcare but not to ...
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                  Relatively new job. Ask again later
# 25    Sometimes I think  about using drugs for my me...
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 1229                                                NaN
# 1230                                                NaN
# 1231                                                NaN
# 1232  I work at a large university with a track reco...
# 1233                                                NaN
# 1234  i'm in a country with social health care so my...
# 1235                                                NaN
# 1236                                                NaN
# 1237                                                NaN
# 1238                                                NaN
# 1239                                                NaN
# 1240                                                NaN
# 1241                                                NaN
# 1242                                                NaN
# 1243                                                NaN
# 1244                                                NaN
# 1245  In australia all organisations of a certain si...
# 1246                                                NaN
# 1247                                                NaN
# 1248                                                NaN
# 1249                                  Bipolar disorder
# 1250                                                NaN
# 1251                                                NaN
# 1252                                                NaN
# 1253                                                NaN
# 1254                                                NaN
# 1255                                                NaN
# 1256                                                NaN
# 1257                                                NaN
# 1258                                                NaN
#
# [1256 rows x 27 columns]

# %%
df['Age'] > 40
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8        True
# 9       False
# 10      False
# 11      False
# 12       True
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18       True
# 19      False
# 20      False
# 21      False
# 22       True
# 23       True
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 1229    False
# 1230    False
# 1231    False
# 1232    False
# 1233    False
# 1234    False
# 1235    False
# 1236     True
# 1237    False
# 1238    False
# 1239    False
# 1240    False
# 1241    False
# 1242    False
# 1243     True
# 1244    False
# 1245    False
# 1246    False
# 1247    False
# 1248     True
# 1249    False
# 1250    False
# 1251    False
# 1252    False
# 1253    False
# 1254    False
# 1255    False
# 1256    False
# 1257     True
# 1258    False
# Name: Age, Length: 1259, dtype: bool

# %%
len(df[df['Age'] > 40])
# Out:
# 150

# %% [markdown]
# ### Example: Find people who reported a family history of mental health conditions. </font>

# %% [markdown]
# Solution:

# %%
family_history_mask = df.family_history=='Yes'
df[family_history_mask].tail(5)
len(df[df['family_history'] == 'Yes'])
# Out:
# 492

# %% [markdown]
# You can use a simple expression like ```df[df['family_history'] == 'Yes']``` or you can make more complex boolean expressions using parentheses:

# %%
df_filtered = df[(df['family_history'] == 'Yes') & (df['treatment'] == 'Yes')] # () for every condition
df_filtered.head()
# Out:
#               Timestamp  Age  Gender         Country state self_employed  \
# 3   2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 6   2014-08-27 11:31:50   35  Female   United States    MI           NaN
# 8   2014-08-27 11:32:39   42  Female   United States    IL           NaN
# 12  2014-08-27 11:33:23   42  female   United States    CA           NaN
# 15  2014-08-27 11:34:00   29  female   United States    IL           NaN
#
#    family_history treatment work_interfere no_employees  \
# 3             Yes       Yes          Often       26-100
# 6             Yes       Yes      Sometimes          1-5
# 8             Yes       Yes      Sometimes      100-500
# 12            Yes       Yes      Sometimes       26-100
# 15            Yes       Yes         Rarely       26-100
#
#                           ...                                       leave  \
# 3                         ...                          Somewhat difficult
# 6                         ...                          Somewhat difficult
# 8                         ...                              Very difficult
# 12                        ...                          Somewhat difficult
# 15                        ...                               Somewhat easy
#
#    mental_health_consequence phys_health_consequence     coworkers  \
# 3                        Yes                     Yes  Some of them
# 6                      Maybe                   Maybe  Some of them
# 8                      Maybe                      No           Yes
# 12                       Yes                     Yes           Yes
# 15                        No                      No           Yes
#
#       supervisor mental_health_interview phys_health_interview  \
# 3             No                   Maybe                 Maybe
# 6             No                      No                    No
# 8            Yes                      No                 Maybe
# 12           Yes                   Maybe                 Maybe
# 15  Some of them                   Maybe                 Maybe
#
#    mental_vs_physical obs_consequence  \
# 3                  No             Yes
# 6          Don't know              No
# 8                  No              No
# 12                 No             Yes
# 15         Don't know              No
#
#                                              comments
# 3                                                 NaN
# 6                                                 NaN
# 8                                                 NaN
# 12                                                NaN
# 15  I have chronic low-level neurological issues t...
#
# [5 rows x 27 columns]

# %% [markdown]
# ### <font color="red">Q1: How many people are willing to discuss a mental health issue with their supervisor or their coworkers? </font>

# %%
len(df[(df['supervisor'] != 'No') | (df['coworkers'] != 'No')])
# Out:
# 1060

# %% [markdown]
# ### <font color="red">Q2: Make a new DataFrame ```df_millenials``` with only millennials (born between 1976 and 1996). Make appropriate assumptions when constructing your filter. </font>

# %%
df_millenials = df[(df['Age'] < 2015 - 1976) & (df['Age'] > 2015 - 1996)]
# should assume the responses were done in the same year 2015

# %% [markdown]
# **NOTE: We will still use df for the following analysis**

# %% [markdown]
# ## Descriptive and Summary Statistics

# %% [markdown]
# Example: What is the mean age of the survey sample?

# %% [markdown]
# Solution:

# %%
df['Age'].mean()
# Out:
# 79428148.31135821

# %% [markdown]
# ### Does that look right?  What should we do?

# %% [markdown]
# ### <font color="red">Q3: What is the _median_ age of the survey sample?  </font>

# %%
df['Age'].median()
# Out:
# 31.0

# %% [markdown]
# ### <font color="red">Q4: Write one line of code to compute basic statistics (mean, standard deviation, min, 25% percentile, etc) about Age  </font>
#
# Hint: see the readings

# %%
df_nount = df[(df['Age'] < 100) & (df['Age'] > 10)]
df_nount['Age'].describe()
# Out:
# count    1252.000000
# mean       32.059904
# std         7.309669
# min        11.000000
# 25%        27.000000
# 50%        31.000000
# 75%        36.000000
# max        72.000000
# Name: Age, dtype: float64

# %% [markdown]
# ## Unique Values, Counts, Membership

# %% [markdown]
# Example: Write one line of code to check unique values of Gender</font>

# %% [markdown]
# Solution:

# %%
df.coworkers.unique()
# Out:
# array(['Some of them', 'No', 'Yes'], dtype=object)

# %%
df.Gender.unique()
# Out:
# array(['Female', 'M', 'Male', 'male', 'female', 'm', 'Male-ish', 'maile',
#        'Trans-female', 'Cis Female', 'F', 'something kinda male?',
#        'Cis Male', 'Woman', 'f', 'Mal', 'Male (CIS)', 'queer/she/they',
#        'non-binary', 'Femake', 'woman', 'Make', 'Nah', 'All', 'Enby',
#        'fluid', 'Genderqueer', 'Female ', 'Androgyne', 'Agender',
#        'cis-female/femme', 'Guy (-ish) ^_^', 'male leaning androgynous',
#        'Male ', 'Man', 'Trans woman', 'msle', 'Neuter', 'Female (trans)',
#        'queer', 'Female (cis)', 'Mail', 'cis male', 'A little about you',
#        'Malr', 'p', 'femail', 'Cis Man',
#        'ostensibly male, unsure what that really means'], dtype=object)

# %% [markdown]
# Example: Write one line of code to count the occurrences of the countries and show the top 5 countries.  </font>

# %% [markdown]
# Solution:

# %%
df.Country.value_counts().head(6)
# Out:
# United States     751
# United Kingdom    185
# Canada             72
# Germany            45
# Ireland            27
# Netherlands        27
# Name: Country, dtype: int64

# %% [markdown]
# Are you sure that's correct?

# %% [markdown]
# ### <font color="red">Q5: Find the unique categories of no_employees. What is the frequency of each category? </font>

# %%
df.no_employees.unique()
df.no_employees.value_counts()
# Out:
# 6-25              290
# 26-100            289
# More than 1000    282
# 100-500           176
# 1-5               162
# 500-1000           60
# Name: no_employees, dtype: int64

# %% [markdown]
# ### <font color="red">Q6: How many Michiganders aged between 20 and 30 sought treatment for a mental health condition? How many did not? </font>
# Show your code and also include a markdown block with a complete sentence or two that answers these questions.

# %%
df[(df.Age >= 20) & (df.Age <= 30) & (df.state == 'MI')]
# filtered['treatment'].value_counts()
# Out:
#                 Timestamp  Age  Gender        Country state self_employed  \
# 149   2014-08-27 12:40:06   29  Female  United States    MI            No
# 191   2014-08-27 12:53:40   28    Male  United States    MI            No
# 215   2014-08-27 13:07:46   27  female  United States    MI           Yes
# 223   2014-08-27 13:15:19   28    Male  United States    MI            No
# 587   2014-08-27 21:55:28   29       f  United States    MI            No
# 629   2014-08-28 02:30:00   28    Male  United States    MI            No
# 1129  2014-08-31 09:19:43   28    male  United States    MI            No
# 1176  2014-09-20 13:51:05   26  Female  United States    MI            No
#
#      family_history treatment work_interfere    no_employees  \
# 149              No        No            NaN         100-500
# 191             Yes       Yes      Sometimes          26-100
# 215             Yes       Yes      Sometimes             1-5
# 223              No       Yes      Sometimes  More than 1000
# 587              No        No          Never          26-100
# 629             Yes       Yes      Sometimes          26-100
# 1129             No        No            NaN  More than 1000
# 1176            Yes       Yes         Rarely         100-500
#
#                             ...                                   leave  \
# 149                         ...                              Don't know
# 191                         ...                           Somewhat easy
# 215                         ...                          Very difficult
# 223                         ...                          Very difficult
# 587                         ...                              Don't know
# 629                         ...                              Don't know
# 1129                        ...                           Somewhat easy
# 1176                        ...                              Don't know
#
#      mental_health_consequence phys_health_consequence     coworkers  \
# 149                      Maybe                      No            No
# 191                      Maybe                   Maybe  Some of them
# 215                         No                      No  Some of them
# 223                        Yes                      No            No
# 587                      Maybe                      No  Some of them
# 629                        Yes                      No  Some of them
# 1129                     Maybe                      No            No
# 1176                     Maybe                   Maybe            No
#
#         supervisor mental_health_interview phys_health_interview  \
# 149   Some of them                      No                 Maybe
# 191             No                      No                 Maybe
# 215             No                      No                    No
# 223   Some of them                      No                    No
# 587   Some of them                      No                 Maybe
# 629   Some of them                      No                    No
# 1129            No                      No                   Yes
# 1176            No                      No                 Maybe
#
#      mental_vs_physical obs_consequence  \
# 149          Don't know              No
# 191                  No              No
# 215          Don't know              No
# 223                  No              No
# 587          Don't know             Yes
# 629          Don't know             Yes
# 1129                 No              No
# 1176                 No              No
#
#                                                comments
# 149                                                 NaN
# 191                                                 NaN
# 215   Many of these questions were difficult to answ...
# 223                                                 NaN
# 587                                                 NaN
# 629                                                 NaN
# 1129                                                NaN
# 1176                                                NaN
#
# [8 rows x 27 columns]

# %% [markdown]
# Replace this with you answer

# %% [markdown]
# ### <font color="red">Q7: Among the people from United States, how many repondents were there from each state?  </font>

# %%
df[df.Country == 'United States']['state'].value_counts()
# Out:
# CA    138
# WA     70
# NY     56
# TN     45
# TX     44
# OH     30
# PA     29
# OR     29
# IL     28
# IN     27
# MI     22
# MN     21
# MA     20
# FL     15
# NC     14
# VA     14
# GA     12
# WI     12
# MO     12
# UT     10
# CO      9
# AL      8
# AZ      7
# MD      7
# NJ      6
# OK      6
# KY      5
# SC      5
# DC      4
# IA      4
# CT      4
# VT      3
# NV      3
# NH      3
# KS      3
# SD      3
# NM      2
# WY      2
# NE      2
# LA      1
# MS      1
# ME      1
# WV      1
# ID      1
# RI      1
# Name: state, dtype: int64

# %% [markdown]
# ## Basic Plots

# %% [markdown]
# Example: Investigate the proportion (%) of people receiving health benefits from their employers.

# %% [markdown]
# Solution:

# %%
df.benefits.value_counts(normalize=True).plot.bar()
df.benefits.value_counts(normalize=True)
# Out:
# Yes           0.378872
# Don't know    0.324067
# No            0.297061
# Name: benefits, dtype: float64

# %% [markdown]
# Example: Create a histogram of the distribution of Age values:

# %%
df.Age.value_counts().plot.hist()

# %% [markdown]
# ### <font color="red">Q8: Experiment with the number of bins in the histogram of the Age distribution:</font>

# %% [markdown]
# Hint: use the bins= option to plot()

# %%
df.Age.value_counts().plot.hist(bins=5)

# %% [markdown]
# ## Discretization and Binning
# Discretization of continuous variables can potentially enhance the goodness-of-fit of a statistical model. Age, for example, is a common varaible to be categorized.
#
# ### <font color="red">Q9: </font> Discretize the age into bins (16,21], (21,25], (25,30], (30, 35], (35,40], (40,50], (50,60], (60,).
#
# How many respondents are in each range?
# Hint: create a list of bin values
# Hint: use pd.cut()
# Hint: use value_counts()

# %%
bins = [15,20,25,30,35,40,50,60,200]

# %%
df['Age_group'] = pd.cut(df.Age, bins) # cut meaning: ? data type: category
pd.cut(df.Age, bins)
df['Age_group'].value_counts()
# Out:
# (25, 30]     362
# (30, 35]     339
# (20, 25]     195
# (35, 40]     185
# (40, 50]     122
# (50, 60]      22
# (15, 20]      22
# (60, 200]      4
# Name: Age_group, dtype: int64

# %% [markdown]
# ## Aggregation

# %% [markdown]
# Example: Find the size of each Age group.

# %% [markdown]
# Solution:

# %%
df.groupby('Age_group').size() # same function as value_counts()
# Out:
# Age_group
# (15, 20]      22
# (20, 25]     195
# (25, 30]     362
# (30, 35]     339
# (35, 40]     185
# (40, 50]     122
# (50, 60]      22
# (60, 200]      4
# dtype: int64

# %% [markdown]
# ### <font color="red">Q10: Find the median age of each state. </font>

# %%
df.groupby('state')['Age'].median()
# Out:
# state
# AL    34.0
# AZ    33.0
# CA    31.0
# CO    31.0
# CT    37.5
# DC    37.5
# FL    34.0
# GA    30.0
# IA    40.0
# ID    55.0
# IL    30.0
# IN    34.0
# KS    39.0
# KY    24.0
# LA    35.0
# MA    32.0
# MD    29.0
# ME    40.0
# MI    34.0
# MN    30.0
# MO    33.5
# MS    33.0
# NC    32.0
# NE    26.0
# NH    34.0
# NJ    32.0
# NM    29.5
# NV    28.0
# NY    29.0
# OH    31.0
# OK    26.5
# OR    32.0
# PA    31.0
# RI    23.0
# SC    30.0
# SD    34.0
# TN    33.0
# TX    31.5
# UT    28.0
# VA    40.5
# VT    34.0
# WA    32.5
# WI    33.0
# WV    23.0
# WY    41.5
# Name: Age, dtype: float64

# %% [markdown]
# # Part 2 (on your own): Exploration of Movie Titles and Movie Cast

# %% [markdown]
# ## Time to load some data:

# %%
titles = pd.read_csv('data/titles.csv', index_col=None)

# %% [markdown]
# The titles DataFrame contains a list of movie titles and release year

# %%
cast = pd.read_csv('data/cast.zip', index_col=None)

# %% [markdown]
# The ```cast``` DataFrame contains the following columns
#
# **title** = name of movie
#
# **year** = year of movie
#
# **name** = name of actor/actress
#
# **type** = actor or actress
#
# **character** = character name
#
# **n** = number in the credits (NaN when not available)

# %%
titles.head()
# Out:
#                      title  year
# 0           The Rising Son  1990
# 1  The Thousand Plane Raid  1969
# 2         Crucea de piatra  1993
# 3                  Country  2000
# 4               Gaiking II  2011

# %%
cast.sample(5)
# Out:
#                         title  year                 name     type  \
# 1318574    The Cherokee Flash  1945           Tom London    actor
# 3030473               Kurbaan  1991               Kunika  actress
# 834633   The Engagement Party  1999          Jacob Goren    actor
# 480606      Way of the Wicked  2014          Jake Croker    actor
# 2041819             Stateside  2004  Carl Matthew Simcox    actor
#
#                           character     n
# 1318574                        Utah   3.0
# 3030473  Mrs. Gayatri Prithvi Singh   9.0
# 834633                       Mendel  11.0
# 480606               Robbie Mueller   4.0
# 2041819                Platoon 1021  83.0

# %% [markdown]
# ### Q11: How many entries are there in the cast table?

# %%
len(cast)
cast.count()
# Out:
# title        3634467
# year         3634467
# name         3634467
# type         3634467
# character    3634467
# n            2244068
# dtype: int64

# %% [markdown]
# ### Q12: How many entries are there in the titles table?

# %%
titles.count()
# Out:
# title    232330
# year     232330
# dtype: int64

# %% [markdown]
# ## Some basic analyses

# %% [markdown]
# ### Q13: What are the two earliest movies?

# %%
# insert code here
titles[titles['year'] == min(titles['year'])]
titles.sort_values('year')
# Out:
#                                                     title  year
# 177757                                         Miss Jerry  1894
# 215272                                 The Startled Lover  1898
# 124505     Reproduction of the Corbett and Jeffries Fight  1899
# 20657   Pierrot's Problem, or How to Make a Fat Wife O...  1900
# 13599                                Family Troubles (II)  1900
# 94998                            Trouble in Hogan's Alley  1900
# 183509                              Soldiers of the Cross  1900
# 209080                                        The Divorce  1903
# 32701                                             Valsons  1905
# 68173                                   La malia dell'oro  1905
# 28222                  The Joe Gans-Battling Nelson Fight  1906
# 214012             Impersonation of Nelson-McGovern Fight  1906
# 166226                        The Story of the Kelly Gang  1906
# 193471                         Highlights from The Mikado  1906
# 145153                                      Lika mot lika  1906
# 127691                               El ciego de la aldea  1907
# 216665                                 Robbery Under Arms  1907
# 206190                                              Faust  1907
# 63550                                            Violante  1907
# 51425                                         Don Quijote  1908
# 130858                                        Os Guaranis  1908
# 225735                                  Gans-Nelson Fight  1908
# 172979                          El pastorcito de Torrente  1908
# 230273                                             Amleto  1908
# 110913                     The Fairylogue and Radio-Plays  1908
# 89045                                      Excelsior (II)  1909
# 147777                                      Yamato zakura  1909
# 76681                            The Scottish Covenanters  1909
# 132520                                     Sonho de Valsa  1909
# 183046                                     Locura de amor  1909
# ...                                                   ...   ...
# 24591                                   Silver from Water  2022
# 217755                                     Darkside: Moon  2022
# 43484                                               Rosie  2022
# 176427                                     Quatro Terra 2  2022
# 88423                                      Clutch Control  2022
# 67019                                   The Burning Skies  2022
# 142551                                    The Devil's Sea  2022
# 26576                               The Cretaceous Period  2022
# 27491                           Oracle: The Last Judgment  2022
# 160801                                             Berlin  2022
# 33204                                         Gnome Alone  2023
# 124226                           Battle in the Antarctica  2023
# 106170                                          St. Cairo  2023
# 130159                              The Supreme Gentleman  2023
# 57605                                           Inside Me  2023
# 160134                               Journey to the Space  2023
# 171822                                   The Good Village  2023
# 103630                                           Garriage  2023
# 72581                                          The League  2023
# 152227                                          Xenomorph  2023
# 85417                                            Avatar 5  2023
# 196677                                            Agartha  2023
# 70051                                           Interplay  2023
# 88936                          The Snowman and the Falcon  2024
# 72471                                             Kennedy  2024
# 10754                       Hyperion: The Wrath of Kronos  2024
# 229718                                         Gods Heart  2025
# 145689                                        Rise of Man  2025
# 102561                                  Settling of Score  2026
# 65488                                         War in Snow  2026
#
# [232330 rows x 2 columns]

# %% [markdown]
# ### Q14: How many movies have the title "Hamlet"?

# %%
len(titles)
len(cast)
titles[titles['title'] == 'Hamlet']['title'].value_counts()
# Out:
# Hamlet    18
# Name: title, dtype: int64

# %% [markdown]
# ### Q15: List all of the "Treasure Island" movies from earliest to most recent

# %%
titles[titles['title'] == 'Treasure Island'].sort_values('year')
# Out:
#                   title  year
# 206027  Treasure Island  1918
# 51287   Treasure Island  1920
# 191050  Treasure Island  1934
# 96934   Treasure Island  1950
# 89534   Treasure Island  1972
# 111343  Treasure Island  1973
# 205397  Treasure Island  1985
# 179354  Treasure Island  1999

# %% [markdown]
# ### Q16: List the supporting roles (having n=2) played by Cary Grant in the 1940s,
# in order by year.

# %%
#(cast.year >= 1940) & (cast.year < 1950)
#(cast.year == 1940) | (cast.year == 1941)... 
# cast.year // 10 == 194
# insert code here
cast[(cast['n'] == 2) & (cast['name'] == 'Cary Grant') & (cast.year // 10 == 194)]
# Out:
#                    title  year        name   type    character    n
# 845513  My Favorite Wife  1940  Cary Grant  actor   Nick Arden  2.0
# 845523    Penny Serenade  1941  Cary Grant  actor  Roger Adams  2.0

# %% [markdown]
# ### Q17: What are the ten most common movie names of all time?

# %%
titles['title'].value_counts()[0:10]
# Out:
# Hamlet                  18
# Carmen                  16
# Macbeth                 15
# The Outsider            12
# Maya                    12
# Temptation              11
# Othello                 11
# The Three Musketeers    11
# Freedom                 11
# Kismet                  11
# Name: title, dtype: int64

# %% [markdown]
# ### Q18: Plot the number of "Hamlet" films made each decade
#
# Make sure your decades are in chronological order on the x-axis

# %%
print(min(titles.year // 10))
print(max(titles.year // 10))
hamlet = titles[titles['title'] == 'Hamlet']
# # titles[(titles['title'] == 'Hamlet') & (titles.year // 10 == 194)]
hamlet['decades'] = hamlet['year'] // 10 * 10
hamlet['decades'].value_counts().plot.bar()

titles.head()
t = titles
t = t[t.title == 'Hamlet']
(t.year // 10 * 10).value_counts().sort_index()
# Out:
# 189
# 202
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# 1910    3
# 1920    1
# 1940    1
# 1950    1
# 1960    2
# 1970    2
# 1980    1
# 1990    2
# 2000    2
# 2010    3
# Name: year, dtype: int64

# %% [markdown]
# ### Q19: Who are the 10 people most often credited as "Herself" in film history?

# %%
# cast[cast['character'] == 'Herself']['name'].value_counts() # have 'Himself'
cast[(cast.name == cast.character) & (cast.type=='actress')].name.value_counts()[0:10]
# Out:
# Laverne Andrews        15
# Maxene Andrews         15
# Patty Andrews          10
# Matutina                8
# The Andrews Sisters     7
# Lena Horne              7
# Zsa Zsa Gabor           7
# Hedda Hopper            6
# Dorothy Lamour          6
# Judy Canova             6
# Name: name, dtype: int64

# %% [markdown]
# ### Q20: What are the 10 most frequent roles that start with the word "Science"?
# Hint: read docs on str.startswith()

# %%
# cast['character']
# cast[cast['character'] re.match('Science?', )]
cast[cast.character.str.startswith('Science')].character.value_counts()[0:10]
# Out:
# Science Teacher         60
# Science Fair Student     9
# Science Student          9
# Science Fair Judge       6
# Science Kid              5
# Science Club Member      5
# Science Reporter         5
# Science Promo Cadet      5
# Science                  4
# Science Officer          3
# Name: character, dtype: int64

# %% [markdown]
# ### Q21: How many leading (n=1) roles were available to actors, and how many to actresses, in the 1950s?

# %%
new = cast[(cast.n==1) & (cast.year // 10 * 10 == 1950)]
print(len(new[new.type=="actor"]))
print(len(new[new.type=="actress"]))
# Out:
# 6616
# 2965

# %% [markdown]
# ### Q22: How many supporting (n=2) roles were available to actors,and how many to actresses, in the 1950s?

# %%
new2 = cast[(cast.n==2) & (cast.year // 10 * 10 == 1950)]
print(len(new2[new2.type=="actor"]))
print(len(new2[new2.type=="actress"]))
print(6616.0 / 2965)
print(4564.0 / 4556)
# Out:
# 4564
# 4556
# 2.23136593592
# 1.00175592625

# %% [markdown]
# ### Q23: Comment on the differences in gender ratios for leading vs. supporting roles in the 1950s.  Does there appear to be a bias?

# %%
### For 1950s, the leading role has gender ratio (actor/actress) about 2.3 so there is some bias. 
### But the ratio for supporting roles is about 1 so there is no significant bias.
